# %%
import temana as tm
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 3*np.pi, 250)
xm = np.linspace(0, 3*np.pi, 25)

# %%
y, ym = tm.genera_signal(x, xm)

# %%
plt.plot(x,y)
plt.plot(xm,ym,'o')

# %%
plt.plot(xm,ym,'o')

# %%
r, rm = tm.genera_ruido(x, xm)
plt.plot(x, r)

# %%
plt.plot(x, y + r)
plt.plot(x, y)
